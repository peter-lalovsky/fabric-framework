# %%
# This notebook is to test (Quality Assurance) notebook "nb_system_function"
# Needed only in DEV environment

# %%
# %run nb_temp_load_cfg

# %%
# %run nb_system_function

# %%
# Freeze/kill above cells
# "%run nb_system_function" is part of "%run nb_temp_load_cfg"

# %% [markdown]
# # System

# %%
if is_debug: print("\n---------- This notenook name: nb_system_function_test - Start ----------\n")

# %%
medallion_name = "System"
if is_debug: print(f"medallion_name: {medallion_name}")

# %%
# Current session info
if is_debug: display(ss.getActiveSession())

# %% [markdown]
# ## Print debug info

# %%
status  = "Success"
fn_name = "fn_print_debug_info"
if is_debug:
    par                  = {}
    par["test_value"]    = "This is test"
    par["another_value"] = "This is another test"
    par["sql_code"] = "SELECT * FROM table_name;"
print(f"Input value (status):  {type(status)} | {status}")
print(f"Input value (fn_name): {type(fn_name)} | {fn_name}")

if is_debug:
    print(f"Input value (par):     {type(par)} | {par}")

time_start = dt.datetime.now()
if is_debug: fn_print_debug_info(status, fn_name, par)
print(f"# Duration: {(dt.datetime.now() - time_start)}")

# %% [markdown]
# ## Get now()

# %%
format_ = "datetime"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "date"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "string"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "year"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "month"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "day"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "hour"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "minute"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "second"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = "default"
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"\n--------------------\n")

format_ = 123
print(f"Input value (format_): {type(format_)} | {format_}")

time_start = dt.datetime.now()
rv_try = fn_get_now(format_)
print(f"# Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

# %% [markdown]
# # Log

# %% [markdown]
# ## Insert into local log

# %%
process_timestamp = global_parameter.process_timestamp
medallion_name    = "System"
source_name       = "fn_local_log_insert"
locals_           = "locals"
alert             = "Success"
alert_description = "Success Description"
print(f"Input value (process_timestamp): {type(process_timestamp)} | {process_timestamp}")
print(f"Input value (source_name): {type(source_name)} | {source_name}")
print(f"Input value (locals_): {type(locals_)} | {locals_}")
print(f"Input value (alert): {type(alert)} | {alert}")
print(f"Input value (alert_description): {type(alert_description)} | {alert_description}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_local_log_insert(
    global_parameter.process_timestamp
    , medallion_name
    , source_name
    , locals_
    , alert
    , alert_description
)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

alert             = "Danger"
alert_description = "Danger Description"

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_local_log_insert(
    global_parameter.process_timestamp
    , medallion_name
    , source_name
    , locals_
    , alert
    , alert_description
)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Insert into table "lh_log.log"

# %%
# %%sql
#
# delete
# from delta.`abfss://abc@onelake.dfs.fabric.microsoft.com/abc/Tables/log`;

# %%
time_start = dt.datetime.now()
rv = fn_lh_log_log_insert()
print(f"Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value: {type(rv)} | {rv}")

# %%
# %%sql
#
# select *
# from delta.`abfss://abc@onelake.dfs.fabric.microsoft.com/abc/Tables/log`
# order by logged_datetime desc;

# %% [markdown]
# ## Insert "global_parameter" into local log

# %%
time_start = dt.datetime.now()
rv = fn_local_log_insert_global_parameter()
print(f"Duration: {(dt.datetime.now() - time_start)}\n")

print(f"Return value: {type(rv)} | {rv}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# Uncomment # test "except" to test exception

# %% [markdown]
# # Lakehouse

# %% [markdown]
# ## Execute PySpark SQL code

# %%
sql_code = "SELECT now() AS test_value;"
print(f"Input value (sql_code): {type(sql_code)} | {sql_code}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_execute_spark_sql(sql_code)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])}")
print(f"Return value (sdf):")
display(rv_try[2])
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

print("\n--------------------\n")

sql_code = "SELECT * FROM Fake;"
print(f"Input value (sql_code): {sql_code} | {type(sql_code)}")

print(f"\n# Execution (except) - Start #")    
time_start = dt.datetime.now()    
rv_except = fn_execute_spark_sql(sql_code)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")
print(f"Return value [3]: {type(rv_except[3])} | {rv_except[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# # Log

# %% [markdown]
# ## Clean up "lh_log.log"

# %%
days_to_keep_log = 1 # 1 = Yesterday; -1 = Tomorrow
print(f"Input value (days_to_keep_log): {type(days_to_keep_log)} | {days_to_keep_log}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_lh_log_log_cleanup(days_to_keep_log)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])} | {rv_try[2]}")

print("\n--------------------\n")

days_to_keep_log = "Fake"

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_lh_log_log_cleanup(days_to_keep_log)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# # Files

# %% [markdown]
# ## Does file exist

# %%
dict_parameter = {
    "technology": "Excel"
    , "frequency": "Daily"
    , "server_name": "srv_n"
    , "database_name": "db_n"
    , "schema_name": "sch_n"
    , "table_name": "tbl_n"
}
file_name  = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_file.txt"
print(f"Input value (file_name): {type(file_name)} | {file_name}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_does_file_exist(file_name, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value[0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value[1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value[2]: {type(rv_try[2])} | {rv_try[2]}")

print("\n--------------------\n")

file_name = 123

print(f"# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_does_file_exist(file_name, dict_parameter)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value[0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value[1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value[2]: {type(rv_except[2])} | {rv_except[2]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Copy file

# %%
dict_parameter = {
    "technology": "Excel"
    , "frequency": "Daily"
    , "server_name": "srv_n"
    , "database_name": "db_n"
    , "schema_name": "sch_n"
    , "table_name": "tbl_n"
}
src  = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_file.txt"
dstn = f"{global_parameter.abfs_path_lh_bronze}/Files/processed/test_file_{global_parameter.process_timestamp}.txt"
print(f"Input value (src): {type(src)} | {src}")
print(f"Input value (dstn): {type(dstn)} | {dstn}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_copy_file(src, dstn, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value[0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value[1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

src = 123

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_copy_file(src, dstn, dict_parameter)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value[0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value[1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Delete file

# %%
dict_parameter = {
    "technology": "Excel"
    , "frequency": "Daily"
    , "server_name": "srv_n"
    , "database_name": "db_n"
    , "schema_name": "sch_n"
    , "table_name": "tbl_n"
}
file_name = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_file.txt"
print(f"Input value (file_name): {type(file_name)} | {file_name}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_delete_file(file_name, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

file_name = 123

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_delete_file(file_name, dict_parameter)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Move file

# %%
dict_parameter = {
    "technology": "Excel"
    , "frequency": "Daily"
    , "server_name": "srv_n"
    , "database_name": "db_n"
    , "schema_name": "sch_n"
    , "table_name": "tbl_n"
}
src  = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_file.txt"
dstn = f"{global_parameter.abfs_path_lh_bronze}/Files/processed/test_file_moved.txt"
print(f"Input value (src): {type(src)} | {src}")
print(f"Input value (dstn): {type(dstn)} | {dstn}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_move_file(src, dstn, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

src = 123

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_move_file(src, dstn, dict_parameter)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Delete folder and all the files and folders in this folder recursively

# %%
folder_name = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_folder"
print(f"Input value (folder_name): {type(folder_name)} | {folder_name}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_delete_folder(folder_name)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

folder_name = 123

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_delete_folder(folder_name)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Delete all files and folders in folder

# %%
folder_name = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/test_folder"
print(f"Input value (folder_name): {type(folder_name)} | {folder_name}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_delete_all_in_folder(folder_name)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {type(rv_try)} | {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print("\n--------------------\n")

folder_name = 123

print(f"# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_delete_all_in_folder(folder_name)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## List folder

# %%
folder_name = f"{global_parameter.abfs_path_lh_bronze}/Files/incoming/Excel"
print(f"Input value (folder_name): {type(folder_name)} | {folder_name}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_list_folder(folder_name)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])} | {rv_try[2]}")
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

# print("\n--------------------\n")

# folder_name = 123

# print(f"# Execution (except) - Start #")
# time_start = dt.datetime.now()
# rv_except = fn_list_folder(folder_name)
# print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

# print(f"Return value: {rv_except}")
# print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
# print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
# print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")
# print(f"Return value [3]: {type(rv_except[3])} | {rv_except[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# # Dataframe, Temp View

# %% [markdown]
# ## Generate dynamic "StructType" list

# %%
sdf = spark.createDataFrame([(1, "column_1", "String"),
    (2, "column_2", "Integer")],
    ["sequence", "column_name", "data_type"]
)
print(f"Input value (sdf) type: {type(sdf)}")
print(f"Input value (sdf):")
sdf.show(truncate = False, n = 5)

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv = fn_get_struct_type(sdf)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv}")
print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [1]: {type(rv[2])} | {rv[2]}")

# Uncomment # test "except" to test exception

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Generate select columns for extract

# %%
sdf_name = "my_df"
sdf = spark.createDataFrame(
    [(1, "column_1", "String", "alias_col_1"),
        (2, "column_2", "Integer", "alias_col_2")],
    ["sequence", "column_name", "data_type", "alias_name"]
)
print(f"Input value (sdf_name): {type(sdf_name)} | {sdf_name}")    
print(f"Input value (sdf) type: {type(sdf)}")
print(f"Input value (sdf):")
sdf.show(truncate = False, n = 5)

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_get_select_column(sdf_name, sdf)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])} | {rv_try[2]}")

print("\n--------------------\n")

sdf = spark.createDataFrame(
    [(1, "column_1", "String", "alias_col_1"),
        (2, "column_2", "Integer", "alias_col_2")],
    ["sequenc", "column_nam", "data_typ", "alias_nam"]
)

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_get_select_column(sdf_name, sdf)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Save SDF in OneLake as table

# %%
sdf = spark.createDataFrame(
    [(1, "column_1", "String", "alias_col_1")
    , (2, "column_2", "Integer", "alias_col_2")]
    , ["sequence", "column_name", "data_type", "alias_name"])
format_        = "delta"
mode           = "overwrite"
path           = f"{global_parameter.abfs_path_lh_bronze}/Tables/test_table_name"
dict_parameter = {
    "technology": "SQl Server"
    , "frequency": "Daily"
    , "server_name": "sql_server"
    , "schema_name": "SalesLT"
    , "table_name": "Address"
}
print(f"Input value (sdf) type: {type(sdf)}")
print(f"Input value (sdf):")
sdf.show(truncate = False, n = 5) 
print(f"Input value (format_): {type(format_)} | {format_}")    
print(f"Input value (mode): {type(mode)} | {mode}")    
print(f"Input value (path): {type(path)} | {path}")    
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")    

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_save_sdf_as_table(sdf, format_, mode, path, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value (status): {type(rv_try)} | {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

sql_code_1 = f"DESCRIBE DETAIL delta.`{   path}`"
sql_code_2 = f"DESCRIBE FORMATTED delta.`{path}`"

rv_1 = spark.sql(sql_code_1)
rv_1.show(truncate = False, vertical = True)

rv_2 = spark.sql(sql_code_2)
rv_2.show(truncate = False, vertical = True)

print(f"Delete test table (status): {fn_delete_folder(path)}")

print("\n--------------------\n")

mode = 123

print(f"# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_save_sdf_as_table(sdf, format_, mode, path, dict_parameter)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Get existing dataframe list

# %%
print(f"\n# Execution - Start #")
time_start = dt.datetime.now()
rv = fn_get_dataframe_list()
print(f"# Execution - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [2]: {type(rv[2])} | {rv[2]}")
print(f"Return value [3]: {type(rv[3])} | {rv[3]}")

# Uncomment # test "except" to test exception

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Get existing temp view list

# %%
print(f"\n# Execution - Start #")
time_start = dt.datetime.now()
rv = fn_get_temp_view_list()
print(f"# Execution - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [2]: {type(rv[2])} | {rv[2]}")
print(f"Return value [3]: {type(rv[3])} | {rv[3]}")

# Uncomment # test "except" to test exception

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# # String

# %% [markdown]
# ## Clean all not alphanumericals in single SDF column

# %%
sdf = spark.createDataFrame([(1, "foo!@#xyz"), (2, "bar@example.com")], ["id", "label"])
print(f"Before:")
sdf.show(truncate = False)
print(f"After:")
col_name = "label"
replace_with = "_"
print(f"Input value (sdf): {type(sdf)} | {sdf}")    
print(f"Input value (col_name): {type(col_name)} | {col_name}")    
print(f"Input value (replace_with): {type(replace_with)} | {replace_with}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_replace_all_not_alphanumericals_in_single_column_in_sdf(sdf, col_name, replace_with)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value:{rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

print(f"Return value [2] type: {type(rv_try[2])}")
print(f"Return value [2] schema:")
rv_try[2].printSchema()
print(f"Return value [2]:")
rv_try[2].show(truncate = False)
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

print("\n--------------------\n")

replace_what = "Fake"

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_replace_all_not_alphanumericals_in_single_column_in_sdf(sdf, replace_what, replace_with)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")
print(f"Return value [3]: {type(rv_except[3])} | {rv_except[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Clean all not alphanumericals in string

# %%
string = "foo!@#xyz"
replace_with = "_"
print(f"Input value (string): {type(string)} | {string}")
print(f"Input value (replace_with): {type(replace_with)} | {replace_with}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_clean_not_alphanumeric_in_string(string, replace_with)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])} | {rv_try[2]}")

print("\n--------------------\n")

print(f"\n# Execution (except) - Start #")
replace_with = 123
time_start = dt.datetime.now()
rv_except = fn_clean_not_alphanumeric_in_string(string, replace_with)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value:{rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Clean accents in SDF column

# %%
sdf = spark.createDataFrame([(1, "foo éèâĉ xyz"), (2, "bar !@# âçă")], ["id", "label"])
print(f"Before:")
sdf.show(truncate = False)
print("sdf (schema):")
sdf.printSchema()
print("Input value (sdf column): \"label\"")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
sdf = sdf.withColumn("new_column", fn_clean_accent_in_sdf_column("label")[2])
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"After:")
print(f"Return value (type): {type(sdf)}")
print(f"Return value (schema):")
sdf.printSchema()
print(f"Return value:")
sdf.show(truncate = False)

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Clean accents in string

# %%
string = "foo   éèçâ xyz"
print(f"Input value (string): {type(string)} | {string}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_clean_accent_in_string(string)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value [2]: {type(rv_try[2])} | {rv_try[2]}")

print("\n--------------------\n")

string = 123

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_clean_accent_in_string(string)
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Replace in all the collumns in SDF

# %%
sdf = spark.createDataFrame(
    [
        (1, "éèâĉ", "NaN")
        , (2, "foo éèâĉ xyz", "éèâĉ")
        , (3, "NaN", "éèâĉ")
    ]
    , ["id", "label", "other"]
)
print(f"Before:")
sdf.show(truncate = False)
replace_what = "NaN"
replace_with = None
print(f"Input value (replace_what): {type(replace_what)} | {replace_what}")
print(f"Input value (replace_with): {type(replace_with)} | {replace_with}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_replace_in_all_columns_in_sdf(sdf, replace_what,  replace_with)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value (sdf) type: {type(rv_try[2])}")
print(f"Return value (sdf) schema:")
rv_try[2].printSchema()
print(f"Return value (sdf):")
rv_try[2].show(truncate = False, n = 5)
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

sdf = rv_try[2] # Apply the changes

replace_what = "éèâĉ"
replace_with = None
print(f"Input value (replace_what): {type(replace_what)} | {replace_what}")
print(f"Input value (replace_with): {type(replace_with)} | {replace_with}")

print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_replace_in_all_columns_in_sdf(sdf, replace_what,  replace_with)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value (sdf) type: {type(rv_try[2])}")
print(f"Return value (sdf) schema:")
rv_try[2].printSchema()
print(f"Return value (sdf):")
rv_try[2].show(truncate = False, n = 5)
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

print("\n--------------------\n")

replace_with = (123, "ABC")

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_replace_in_all_columns_in_sdf(sdf, replace_what,  replace_with)    
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")
print(f"Return value [3]: {type(rv_except[3])} | {rv_except[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# ## Replace in single collumn in SDF

# %%
sdf = spark.createDataFrame([("XYZ", "ABC"), ("SDGH", "foo 123 xyz"), ("SDF 123", "NaN")], ["id", "label"])
print(f"Before:")
sdf.show(truncate = False)
column_name = "label"
replace_what = " "
replace_with = "_"
print(f"Input value (column_name): {type(column_name)} | {column_name}")
print(f"Input value (replace_what): {type(replace_what)} | {replace_what}")
print(f"Input value (replace_with): {type(replace_with)} | {replace_with}")
    
print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_replace_in_single_column_in_sdf(sdf, column_name, replace_what,  replace_with)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")
print(f"Return value (sdf) type:       {type(rv_try[2])}")
print(f"Return value (sdf) schema:")
rv_try[2].printSchema()
print(f"Return value (sdf):")
rv_try[2].show(truncate = False, n = 5)
print(f"Return value [3]: {type(rv_try[3])} | {rv_try[3]}")

print("\n--------------------\n")

replace_with = (123, "ABC")

print(f"\n# Execution (except) - Start #")
time_start = dt.datetime.now()
rv_except = fn_replace_in_single_column_in_sdf(sdf, column_name, replace_what,  replace_with)    
print(f"# Execution (except) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_except}")
print(f"Return value [0]: {type(rv_except[0])} | {rv_except[0]}")
print(f"Return value [1]: {type(rv_except[1])} | {rv_except[1]}")
print(f"Return value [2]: {type(rv_except[2])} | {rv_except[2]}")
print(f"Return value [3]: {type(rv_except[3])} | {rv_except[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %%
fn_lh_log_log_insert()

# %% [markdown]
# # Email

# %% [markdown]
# ## Get report

# %%
global_parameter.process_timestamp = "20240910_083736637"
report_type = "Error"
print(f"global_parameter.process_timestamp: {type(global_parameter.process_timestamp)} | {global_parameter.process_timestamp}")
print(f"Input value (report_type): {type(report_type)} | {report_type}")

print(f"\n# Execution (Error) - Start #")
time_start = dt.datetime.now()
rv = fn_get_email_report(report_type)
print(f"# Execution (Error) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv}")
print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [2]: {type(rv[2])} | {rv[2]}")
print(f"Return value [2] (HTML):")
displayHTML(rv[2])
print(f"Return value [2]: {type(rv[3])} | {rv[3]}")

print("\n--------------------\n")

global_parameter.process_timestamp = "20240910_083736637"
report_type = "Success"
print(f"global_parameter.process_timestamp: {type(global_parameter.process_timestamp)} | {global_parameter.process_timestamp}")
print(f"Input value (report_type): {type(report_type)} | {report_type}")

print(f"\n# Execution (Success) - Start #")
time_start = dt.datetime.now()
rv = fn_get_email_report(report_type)
print(f"# Execution (Success) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv}")
print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [2]: {type(rv[2])} | {rv[2]}")
print(f"Return value [2] (HTML):")
displayHTML(rv[2])
print(f"Return value [2]: {type(rv[3])} | {rv[3]}")

print("\n--------------------\n")

global_parameter.process_timestamp = "20240910_083736638"
report_type = "Success"
print(f"global_parameter.process_timestamp: {type(global_parameter.process_timestamp)} | {global_parameter.process_timestamp}")
print(f"Input value (report_type): {type(report_type)} | {report_type}")

print(f"\n# Execution (Success - empty) - Start #")
time_start = dt.datetime.now()
rv = fn_get_email_report(report_type)
print(f"# Execution (Success - empty) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv}")
print(f"Return value [0]: {type(rv[0])} | {rv[0]}")
print(f"Return value [1]: {type(rv[1])} | {rv[1]}")
print(f"Return value [2]: {type(rv[2])} | {rv[2]}")
print(f"Return value [2] (HTML):")
displayHTML(rv[2])
print(f"Return value [2]: {type(rv[3])} | {rv[3]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %% [markdown]
# # API

# %% [markdown]
# ## Execute API Request

# %%
is_debug = False

# %%
# Test GET, JSON

method          = "GET"
response_format = "JSON"
dict_parameter  = {
    "url": "https://api.github.com/events"
    , "headers": {"Content-Type": "application/json", "User-Agent": "zPL Concept"}
    , "params": {"key1": "value1", "key2": "value2"}
    , "auth": ("Username", "Password")
}

print(f"Input value (method): {type(method)} | {method}")
print(f"Input value (response_format): {type(response_format)} | {response_format}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")
    
print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_api_request(method, response_format, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %%
# Test GET, XML

method          = "GET"
response_format = "XML"
dict_parameter  = {
    "url": "https://cdn.animenewsnetwork.com/encyclopedia/api.xml?title=4658"
    , "headers": {"Content-Type": "application/json", "User-Agent": "zPL Concept"}
    , "params": {"title": 4658}
    , "auth": ("Username", "Password")
}

print(f"Input value (method): {type(method)} | {method}")
print(f"Input value (response_format): {type(response_format)} | {response_format}")
print(f"Input value (dict_parameter): {type(dict_parameter)} | {dict_parameter}")
    
print(f"\n# Execution (try) - Start #")
time_start = dt.datetime.now()
rv_try = fn_api_request(method, response_format, dict_parameter)
print(f"# Execution (try) - End (duration: {(dt.datetime.now() - time_start)}) #\n")

print(f"Return value: {rv_try}")
print(f"Return value [0]: {type(rv_try[0])} | {rv_try[0]}")
print(f"Return value [1]: {type(rv_try[1])} | {rv_try[1]}")

pdf_log.reset_index(drop = True, inplace = True)
display(pdf_log.sort_values(by = "logged_datetime", ascending = False))

# %%
#def fn_api_request(
if 1==1:
    method = "GET"
    response_format = "XML"
    dict_parameter = {
    "url": "https://cdn.animenewsnetwork.com/encyclopedia/api.xml?title=4658"
    , "headers": {"Content-Type": "application/json", "User-Agent": "zPL Concept"}
    , "params": {"title": 4658}
    , "auth": ("Username", "Password")
}
# ):
#     fn_name        = stk()[0][3]
#     caller_fn_name = stk()[1].function.replace("<module>", "")
#     if is_debug: par = {}

#     try:
    if 1==1:
        arguments = ""
        for key, val in dict_parameter.items():
            if str(type(val)) == "<class 'str'>": val = f"\"{val}\""
            arguments += f"{key} = {val}, "
        arguments = arguments[:-2]
        
        if   method == "GET":  request_code = f"req.get({arguments})"
        elif method == "POST": request_code = f"req.post({arguments})"
        
        response             = eval(request_code)
        is_response_ok       = response.ok
        response_status_code = response.status_code
        response_reason      = response.reason
        response_status      = f"{response_status_code} ({response_reason}"
        response.raise_for_status()
        
        if is_response_ok:
            alert             = "Success"
            alert_description = f"Response status: {response_status})"
            if response_format == "JSON": return_value = (f"{response_status})", response.json())
            if response_format == "XML":  return_value = (f"{response_status})", response.text)
        else:
            alert             = "Danger"
            alert_description = f"Response status: {response_status}"

        #return return_value
        
        

        print(return_value)
            
    # except req.exceptions.HTTPError as http_err:
    #     alert             = "Danger"
    #     alert_description = f"{response_status}: HTTP Error)"
    #     return_value      = (f"{response_status}: HTTP Error)", http_err)

    #     return return_value
    # except req.exceptions.ConnectionError as conn_err:
    #     alert             = "Danger"
    #     alert_description = f"{response_status}: Connection Error)"
    #     return_value      = (f"{response_status}: Connection Error)", conn_err)

    #     return return_value
    # except req.exceptions.Timeout as timeout:
    #     alert             = "Danger"
    #     alert_description = f"{response_status}: Timeout)"
    #     return_value      = (f"{response_status}: Timeout)", timeout)

    #     return return_value
    # except req.exceptions.RequestException as req_ex:
    #     alert             = "Danger"
    #     alert_description = f"{response_status}: Request Exception)"
    #     return_value      = (f"{response_status}: Request Exception)", req_ex)

    #     return return_value
    # finally:
    #     if is_debug:
    #         par["locals"] = locals()
    #         if "sdf" in locals(): par["sdf"] = sdf.show(n = 5)
    #         fn_print_debug_info(alert, fn_name, par)
    #         del par

    #     # Keep only the first 3 elements of "return_value" in log
    #     if response_format == "JSON":
    #         list_return_value = list(return_value)
    #         list_return_value[1] = list_return_value[1][:3]
    #         return_value = tuple(list_return_value)
    #         del list_return_value
    #     if response_format == "XML":
        
    #     fn_local_log_insert(global_parameter.process_timestamp, medallion_name, fn_name, fn_locals_to_json(locals())[2], alert, alert_description)

# %%
if is_debug: print("\n---------- This notenook name: nb_system_function_test - End ----------\n")
